# %% [markdown]
# # **Cargar el archivo CSV que contiene los datos tratados anteriormente**

# %% [markdown]
# Carga el archivo CSV que contiene los datos tratados anteriormente.
#
# 📂 **Atención**: Utiliza el mismo archivo que limpiaste y organizaste en la Parte 1 del desafío Telecom X. Debe contener solo las columnas relevantes, ya con los datos corregidos y estandarizados.

# %%
import pandas as pd
import numpy as np
import sklearn
import seaborn as sns
import yellowbrick

# %%
URL = 'https://raw.githubusercontent.com/Bufudyne/Telecom-Parte-2/refs/heads/master/datos_churn_filtrados.csv'

datos = pd.read_csv(URL)
datos
# Out:
#       customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     0002-ORFBO      0       0              0        1           1       9
# 1     0003-MKNFE      0       1              0        0           0       9
# 2     0004-TLHLJ      1       1              0        0           0       4
# 3     0011-IGKFF      1       1              1        1           0      13
# 4     0013-EXCHZ      1       0              1        1           0       3
# ...          ...    ...     ...            ...      ...         ...     ...
# 7038  9987-LUTYD      0       0              0        0           0      13
# 7039  9992-RRAMN      1       1              0        1           0      22
# 7040  9992-UJOEL      0       1              0        0           0       2
# 7041  9993-LHIEB      0       1              0        1           1      67
# 7042  9995-HOTOH      0       1              0        1           1      63
#
#       PhoneService  MultipleLines  InternetService  ...  StreamingMovies  \
# 0                1              0                0  ...                0
# 1                1              1                0  ...                1
# 2                1              0                1  ...                0
# 3                1              0                1  ...                1
# 4                1              0                1  ...                0
# ...            ...            ...              ...  ...              ...
# 7038             1              0                0  ...                0
# 7039             1              1                1  ...                1
# 7040             1              0                0  ...                0
# 7041             1              0                0  ...                1
# 7042             0             -1                0  ...                1
#
#       Contract  PaperlessBilling  PaymentMethod  ChargesMonthly  ChargesTotal  \
# 0            1                 1              1           65.60        593.30
# 1            0                 0              1           59.90        542.40
# 2            0                 1              0           73.90        280.85
# 3            0                 1              0           98.00       1237.85
# 4            0                 1              1           83.90        267.40
# ...        ...               ...            ...             ...           ...
# 7038         1                 0              1           55.15        742.90
# 7039         0                 1              0           85.10       1873.70
# 7040         0                 1              1           50.30         92.75
# 7041         2                 0              1           67.85       4627.65
# 7042         2                 0              0           59.00       3707.60
#
#       Cuentas_Diarias  tenure_interval  TotalPayed  TotalPayed_interval
# 0            2.186667          (6, 12]      590.40          (500, 1000]
# 1            1.996667          (6, 12]      539.10          (500, 1000]
# 2            2.463333           (0, 6]      295.60             (0, 500]
# 3            3.266667         (12, 18]     1274.00         (1000, 1500]
# 4            2.796667           (0, 6]      251.70             (0, 500]
# ...               ...              ...         ...                  ...
# 7038         1.838333         (12, 18]      716.95          (500, 1000]
# 7039         2.836667         (18, 24]     1872.20         (1500, 2000]
# 7040         1.676667           (0, 6]      100.60             (0, 500]
# 7041         2.261667         (66, 72]     4545.95         (4500, 5000]
# 7042         1.966667         (60, 66]     3717.00         (3500, 4000]
#
# [7043 rows x 25 columns]

# %%
for column in datos.columns:
  print('\r\n*******\n')
  print(column, ':', datos[column].unique())
# Out:
# *******
#
# customerID : ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
#
# *******
#
# Churn : [0 1]
#
# *******
#
# gender : [0 1]
#
# *******
#
# SeniorCitizen : [0 1]
#
# *******
#
# Partner : [1 0]
#
# *******
#
# Dependents : [1 0]
#
# *******
#
# tenure : [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 37 49 66 67
#  20 43 59 12 27  2 25 29 14 35 64 39 40 11  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 31 36 17 18 51 38 42
#   0]
#
# *******
#
# PhoneService : [1 0]
#
# *******
#
# MultipleLines : [ 0  1 -1]
#
# *******
#
# InternetService : [ 0  1 -1]
#
# *******
#
# OnlineSecurity : [ 0  1 -1]
#
# *******
#
# OnlineBackup : [ 1  0 -1]
#
# *******
#
# DeviceProtection : [ 0  1 -1]
#
# *******
#
# TechSupport : [ 1  0 -1]
#
# *******
#
# StreamingTV : [ 1  0 -1]
#
# *******
#
# StreamingMovies : [ 0  1 -1]
#
# *******
#
# Contract : [1 0 2]
#
# *******
#
# PaperlessBilling : [1 0]
#
# *******
#
# PaymentMethod : [1 0 3 2]
#
# *******
#
# ChargesMonthly : [65.6  59.9  73.9  ... 91.75 68.8  67.85]
#
# *******
#
# ChargesTotal : [ 593.3   542.4   280.85 ...  742.9  4627.65 3707.6 ]
#
# *******
#
# Cuentas_Diarias : [2.18666667 1.99666667 2.46333333 ... 3.05833333 2.29333333 2.26166667]
#
# *******
#
# tenure_interval : ['(6, 12]' '(0, 6]' '(12, 18]' '(66, 72]' '(60, 66]' '(48, 54]' '(54, 60]'
#  '(30, 36]' '(42, 48]' '(18, 24]' '(24, 30]' '(36, 42]' nan]
#
# *******
#
# TotalPayed : [ 590.4   539.1   295.6  ... 1872.2  4545.95 3717.  ]
#
# *******
#
# TotalPayed_interval : ['(500, 1000]' '(0, 500]' '(1000, 1500]' '(7500, 8000]' '(5000, 5500]'
#  '(5500, 6000]' '(2000, 2500]' '(8000, 8500]' '(7000, 7500]'
#  '(2500, 3000]' '(6500, 7000]' '(1500, 2000]' '(3000, 3500]'
#  '(4500, 5000]' '(6000, 6500]' '(3500, 4000]' '(4000, 4500]' nan]

# %% [markdown]
# # **Eliminar columnas irrelevantes**

# %% [markdown]
# Eliminar columnas irrelevantes o que se usaron para graficar:
# *   customerID
# *   gender
# *   Partner
# *   Dependents
# *   Cuentas_Diarias (se deduce desde ChargesMonthly)
# *   tenure_interval
# *   TotalPayed
# *   TotalPayed_interval

# %%
# eliminamos las columnas que irrelevantes o que se usaron para graficar
datos = datos.drop(columns=['customerID', 'gender', 'Partner', 'Dependents'
                            , 'Cuentas_Diarias', 'tenure_interval','TotalPayed', 'TotalPayed_interval'
                            ])
datos.columns
# Out:
# Index(['Churn', 'SeniorCitizen', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'ChargesMonthly', 'ChargesTotal'],
#       dtype='object')

# %% [markdown]
# ## **Revisar los valores de columnas codependientes**

# %% [markdown]
# Revisar los valores de columnas codependientes de `PhoneService=0 `y `InternetService=0`

# %% [markdown]
# 1.   Si no tiene contratado servicio de internet, no deben existir los servicios dependientes de ese

# %%
#                                  | DeviceProtection==1 \
datos.query("(InternetService==0)&( OnlineSecurity==1 \
                                  | OnlineBackup==1 \
                                  | TechSupport==1 \
                                  | StreamingTV==1 \
                                  | StreamingMovies==1 )"
      )[['InternetService', 'OnlineSecurity', 'OnlineBackup'
        , 'TechSupport', 'StreamingTV', 'StreamingMovies', 'DeviceProtection']].value_counts()
# Out:
# InternetService  OnlineSecurity  OnlineBackup  TechSupport  StreamingTV  StreamingMovies  DeviceProtection
# 0                1               1             1            1            1                1                   143
#                                  0             0            0            0                0                   106
#                  0               1             0            0            0                0                    97
#                  1               0             1            1            1                1                    79
#                                  1             1            0            0                0                    78
#                                                                                                              ...
#                  0               1             0            1            0                1                    12
#                  1               1             0            1            1                0                    12
#                  0               1             1            0            1                1                    11
#                  1               0             0            1            0                1                    11
#                                  1             0            1            0                1                    11
# Name: count, Length: 62, dtype: int64

# %% [markdown]
# 2.   Si existe la información sobre protección del equipo, cuando no se ha contratado ni servicio de internet ni telefónico

# %%
datos[(datos['DeviceProtection']==1) & ((datos['PhoneService']==0) & (datos['InternetService']==0))][['InternetService', 'PhoneService', 'DeviceProtection']].value_counts()
# Out:
# InternetService  PhoneService  DeviceProtection
# 0                0             1                   305
# Name: count, dtype: int64

# %% [markdown]
# 3.   Si existe la información sobre multiples lineas telefónicas, cuando el servicio telefónico no esta contratado

# %%
datos[(datos['PhoneService']==0)&(datos['MultipleLines']==1)].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ## **Volver a los valores categóricos**

# %% [markdown]
# Volvemos a los valores categóricos, para su posterior transformación en las columnas con OneHotEncoder.

# %%
datos['MultipleLines'] = datos['MultipleLines'].map({0:'No', 1:'Yes', -1:'No phone service'})
datos['InternetService'] = datos['InternetService'].map({0:'DSL', 1:'Fiber optic', -1:'No'})
datos['SeniorCitizen'] = datos['SeniorCitizen'].map({0:'No', 1:'Yes'})
datos['OnlineSecurity'] = datos['OnlineSecurity'].map({0:'No', 1:'Yes', -1:'No internet service'})
datos['OnlineBackup'] = datos['OnlineBackup'].map({0:'No', 1:'Yes', -1:'No internet service'})
datos['DeviceProtection'] = datos['DeviceProtection'].map({0:'No', 1:'Yes', -1:'No internet service'})
datos['TechSupport'] = datos['TechSupport'].map({0:'No', 1:'Yes', -1:'No internet service'})
datos['StreamingTV'] = datos['StreamingTV'].map({0:'No', 1:'Yes', -1:'No internet service'})
datos['StreamingMovies'] = datos['StreamingMovies'].map({0:'No', 1:'Yes', -1:'No internet service'})
datos['Contract'] = datos['Contract'].map({0:'Month-to-month', 1:'One year', 2:'Two year'})
datos['PaymentMethod'] = datos['PaymentMethod'].map({0:'Electronic check', 1:'Mailed check', 2:'Bank transfer (automatic)', 3:'Credit card (automatic)'})
datos['PhoneService'] = datos['PhoneService'].map({0:'No', 1:'Si'})

# %% [markdown]
# # **Transformar las variables categóricas a formato numérico**

# %% [markdown]
# 1.   Realizar la transformación de las variables categóricas, para hacerlas compatibles con los algoritmos de machine learning. Transformar formato de texto, al formato numérico con el `OneHotEncoder`, utilizando el parámetro `drop='if_binary'` si alguna variable tiene solo 2 categorías.
# 2.   Realizar la separación de la base de datos de churn entre las **variables explicativas**, almacenando en una variable `X` y la **variable objetivo** en `y`.

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
import pandas as pd

# Ejemplo de tus columnas categóricas
categoricas = ['MultipleLines', 'InternetService', 'SeniorCitizen', 'OnlineSecurity', 'OnlineBackup'
              , 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies'
              , 'Contract', 'PaymentMethod', 'PhoneService'
              ]
# OneHotEncoder sin verbose_feature_names_out
ohe = OneHotEncoder(drop='if_binary')

# ColumnTransformer
ct = ColumnTransformer(
    transformers=[
        ('ohe', ohe, categoricas)
    ],
    remainder='passthrough',
    sparse_threshold=0
)

# Simulamos tus datos
# Transformando las variables explicativas
#print('Transformando las variables explicativas')
X = datos.drop('Churn', axis=1)
y = datos['Churn']

# Ajustamos y transformamos
datos_transformados = ct.fit_transform(X)

# Obtenemos nombres de columnas SIN prefijo "ohe__"
nombres_columnas = [
    col.split("__")[-1] for col in ct.get_feature_names_out()
]

# Creamos DataFrame limpio
X = pd.DataFrame(datos_transformados, columns=nombres_columnas)

print(f'\r\nColumnas transformadas: {X.columns}')
print(f'\r\nCantidad de columnas: {len(X.columns)}')
# Out:
# Columnas transformadas: Index(['MultipleLines_No', 'MultipleLines_No phone service',
#        'MultipleLines_Yes', 'InternetService_DSL',
#        'InternetService_Fiber optic', 'InternetService_No',
#        'SeniorCitizen_Yes', 'OnlineSecurity_No',
#        'OnlineSecurity_No internet service', 'OnlineSecurity_Yes',
#        'OnlineBackup_No', 'OnlineBackup_No internet service',
#        'OnlineBackup_Yes', 'DeviceProtection_No',
#        'DeviceProtection_No internet service', 'DeviceProtection_Yes',
#        'TechSupport_No', 'TechSupport_No internet service', 'TechSupport_Yes',
#        'StreamingTV_No', 'StreamingTV_No internet service', 'StreamingTV_Yes',
#        'StreamingMovies_No', 'StreamingMovies_No internet service',
#        'StreamingMovies_Yes', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check',
#        'PhoneService_Si', 'tenure', 'PaperlessBilling', 'ChargesMonthly',
#        'ChargesTotal'],
#       dtype='object')
#
# Cantidad de columnas: 37

# %%
X.sample(5)
# Out:
#       MultipleLines_No  MultipleLines_No phone service  MultipleLines_Yes  \
# 4757               1.0                             0.0                0.0
# 87                 1.0                             0.0                0.0
# 5008               0.0                             0.0                1.0
# 2374               1.0                             0.0                0.0
# 3871               0.0                             0.0                1.0
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 4757                  1.0                          0.0                 0.0
# 87                    0.0                          0.0                 1.0
# 5008                  0.0                          1.0                 0.0
# 2374                  1.0                          0.0                 0.0
# 3871                  0.0                          1.0                 0.0
#
#       SeniorCitizen_Yes  OnlineSecurity_No  \
# 4757                0.0                0.0
# 87                  0.0                0.0
# 5008                0.0                1.0
# 2374                0.0                0.0
# 3871                0.0                0.0
#
#       OnlineSecurity_No internet service  OnlineSecurity_Yes  ...  \
# 4757                                 0.0                 1.0  ...
# 87                                   1.0                 0.0  ...
# 5008                                 0.0                 0.0  ...
# 2374                                 0.0                 1.0  ...
# 3871                                 0.0                 1.0  ...
#
#       Contract_Two year  PaymentMethod_Bank transfer (automatic)  \
# 4757                1.0                                      1.0
# 87                  0.0                                      0.0
# 5008                1.0                                      0.0
# 2374                1.0                                      0.0
# 3871                0.0                                      0.0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 4757                                    0.0                             0.0
# 87                                      0.0                             0.0
# 5008                                    0.0                             1.0
# 2374                                    1.0                             0.0
# 3871                                    0.0                             1.0
#
#       PaymentMethod_Mailed check  PhoneService_Si  tenure  PaperlessBilling  \
# 4757                         0.0              1.0    67.0               1.0
# 87                           1.0              1.0     3.0               0.0
# 5008                         0.0              1.0    69.0               0.0
# 2374                         0.0              1.0    51.0               0.0
# 3871                         0.0              1.0    62.0               0.0
#
#       ChargesMonthly  ChargesTotal
# 4757           60.40       3953.70
# 87             19.85         63.75
# 5008          104.00       7028.50
# 2374           60.50       3121.45
# 3871          102.00       6529.25
#
# [5 rows x 37 columns]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 37 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   MultipleLines_No                         7043 non-null   float64
#  1   MultipleLines_No phone service           7043 non-null   float64
#  2   MultipleLines_Yes                        7043 non-null   float64
#  3   InternetService_DSL                      7043 non-null   float64
#  4   InternetService_Fiber optic              7043 non-null   float64
#  5   InternetService_No                       7043 non-null   float64
#  6   SeniorCitizen_Yes                        7043 non-null   float64
#  7   OnlineSecurity_No                        7043 non-null   float64
#  8   OnlineSecurity_No internet service       7043 non-null   float64
#  9   OnlineSecurity_Yes                       7043 non-null   float64
#  10  OnlineBackup_No                          7043 non-null   float64
#  11  OnlineBackup_No internet service         7043 non-null   float64
#  12  OnlineBackup_Yes                         7043 non-null   float64
#  13  DeviceProtection_No                      7043 non-null   float64
#  14  DeviceProtection_No internet service     7043 non-null   float64
#  15  DeviceProtection_Yes                     7043 non-null   float64
#  16  TechSupport_No                           7043 non-null   float64
#  17  TechSupport_No internet service          7043 non-null   float64
#  18  TechSupport_Yes                          7043 non-null   float64
#  19  StreamingTV_No                           7043 non-null   float64
#  20  StreamingTV_No internet service          7043 non-null   float64
#  21  StreamingTV_Yes                          7043 non-null   float64
#  22  StreamingMovies_No                       7043 non-null   float64
#  23  StreamingMovies_No internet service      7043 non-null   float64
#  24  StreamingMovies_Yes                      7043 non-null   float64
#  25  Contract_Month-to-month                  7043 non-null   float64
#  26  Contract_One year                        7043 non-null   float64
#  27  Contract_Two year                        7043 non-null   float64
#  28  PaymentMethod_Bank transfer (automatic)  7043 non-null   float64
#  29  PaymentMethod_Credit card (automatic)    7043 non-null   float64
#  30  PaymentMethod_Electronic check           7043 non-null   float64
#  31  PaymentMethod_Mailed check               7043 non-null   float64
#  32  PhoneService_Si                          7043 non-null   float64
#  33  tenure                                   7043 non-null   float64
#  34  PaperlessBilling                         7043 non-null   float64
#  35  ChargesMonthly                           7043 non-null   float64
#  36  ChargesTotal                             7043 non-null   float64
# dtypes: float64(37)
# memory usage: 2.0 MB

# %% [markdown]
# # **Verificar la proporción de cancelación (Churn)**

# %% [markdown]
# Calcular la proporción de clientes que cancelaron en relación con los que permanecieron activos. Evalúar si existe un desbalance entre las clases, ya que esto puede impactar en los modelos predictivos y en el análisis de los resultados.

# %%
y.value_counts()
# Out:
# Churn
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %% [markdown]
# Las clases estan muy desequilibradas, por lo tanto, es necesario a balancear la clase con valor Churn=1, pero se debe hacer solo sobre el conjunto de datos de entrenamiento. Por lo tanto, antes, para no afectar a la validación, los datos deben ser separados.

# %% [markdown]
# # Dividiendo los datos entre entrenamiento, validacón y prueba

# %% [markdown]
# Para comprender si el modelo realmente está aprendiendo de los datos, aplicamos el estrategia holdout, separando los datos en tres partes: datos de entrenamiento, validación y prueba:
# *   El **conjunto de entrenamiento** se utiliza para entrenar los modelos. A partir de este conjunto, los modelos identifican patrones en los datos.
# *   El **conjunto de validación** se emplea para evaluar el desempeño de diferentes modelos con datos nuevos que no fueron utilizados en el entrenamiento.
# *   El **conjunto de prueba** se mantiene separado desde el inicio para simular datos del mundo real. No se utiliza en ninguna etapa del entrenamiento ni de la validación, sirviendo como una estimación de la capacidad del modelo elegido para generalizar y predecir nuevos datos.
#
# Realizaremos la división de los datos entre entrenamiento, validación y prueba en las siguentes proporciones:
# *   El 5% de los datos para prueba
# *   El 25% para validación
#
# En el momento de la separación, usaremos el parámetro `stratify` a partir de la variable objetivo para mantener la proporción de los datos de la variable objetivo para el entrenamiento y el testeo.

# %%
from sklearn.model_selection import train_test_split

# %%
X, X_test, y, y_test = train_test_split(X, y, test_size=0.05, stratify=y, random_state=5)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, stratify=y, random_state=5)

# %% [markdown]
# # **Análisis dirigido**

# %% [markdown]
# Tiempo de contrato vs Tipo de contrato

# %%
import plotly.express as px

px.box(datos, x='tenure', color='Contract')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e220615d-1454-47db-a083-a988c4a73a96" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e220615d-1454-47db-a083-a988c4a73a96")) {                    Plotly.newPlot(                        "e220615d-1454-47db-a083-a988c4a73a96",                        [{"alignmentgroup":"True","hovertemplate":"Contract=One year\u003cbr\u003etenure=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"One year","marker":{"color":"#636efa"},"name":"One year","notched":false,"offsetgroup":"One year","orientation":"h","showlegend":true,"x":[9,34,45,50,55,26,37,49,66,67,27,25,14,35,64,70,57,58,49,50,44,44,71,58,69,70,25,54,71,30,10,63,60,48,52,67,23,19,41,11,16,71,11,71,70,39,60,55,28,9,58,34,40,54,58,15,51,25,28,41,53,54,62,41,45,32,23,24,60,28,62,18,35,57,51,18,69,63,60,41,45,56,65,22,40,62,48,53,6,22,48,71,50,65,46,53,40,44,45,36,55,52,51,51,70,52,46,62,66,58,67,43,24,52,45,15,24,47,45,18,64,34,59,54,53,23,6,61,38,36,54,52,54,13,42,49,11,37,26,26,33,68,56,7,62,41,38,68,12,25,67,1,25,59,69,63,69,56,45,66,68,14,44,69,24,61,18,64,50,30,51,60,33,38,49,28,53,19,3,23,23,43,8,64,27,49,59,68,44,15,70,35,68,29,52,54,68,72,18,41,14,64,22,50,54,67,46,48,40,20,7,23,18,33,32,12,29,26,66,70,58,49,58,35,70,58,61,17,61,27,48,19,57,51,60,62,42,68,33,48,70,12,23,42,71,39,61,61,12,46,42,51,53,10,54,60,39,35,18,34,51,51,64,52,24,42,20,31,71,36,29,11,39,39,48,16,41,55,47,21,33,45,10,22,20,70,27,58,46,37,33,27,31,60,63,68,29,41,17,44,68,43,27,40,37,13,46,71,34,58,27,17,72,39,1,51,58,33,9,61,7,72,62,32,29,49,40,57,23,12,20,38,48,32,57,51,48,44,7,39,40,46,30,58,46,62,17,50,37,41,61,59,66,18,11,54,20,58,39,31,4,50,60,25,34,42,52,57,7,47,65,72,35,65,59,50,13,14,40,70,53,64,71,33,67,65,8,56,7,8,22,5,65,55,36,64,39,46,32,41,63,22,47,35,13,71,53,56,52,25,26,49,28,49,29,61,15,35,53,17,6,68,35,35,63,72,59,40,21,68,11,37,0,56,30,8,46,56,59,50,62,1,67,7,57,3,40,62,50,37,48,63,41,68,1,47,14,67,61,60,59,22,14,17,10,60,55,5,23,70,49,67,26,61,66,34,18,16,53,52,28,34,32,68,59,28,71,28,64,72,36,59,67,8,13,44,51,44,29,28,14,58,43,68,25,10,28,36,70,56,35,23,26,22,47,34,20,53,66,58,45,51,57,10,24,35,55,31,17,13,61,32,43,62,60,58,52,50,45,32,26,61,15,10,66,35,61,28,36,67,7,65,59,66,24,72,14,55,12,71,40,12,72,54,72,45,10,60,41,53,4,44,42,47,57,70,36,26,38,31,31,41,51,19,38,34,55,48,20,34,39,56,69,4,35,58,12,55,51,46,41,63,36,46,26,12,21,68,68,66,68,28,7,69,16,10,68,13,70,39,20,48,53,56,17,56,34,32,17,3,44,14,25,12,64,20,42,15,61,2,69,36,38,61,46,31,42,42,54,42,51,9,46,8,55,52,59,47,41,22,52,45,56,53,25,60,56,16,20,51,35,22,53,54,62,55,17,64,18,60,50,44,57,18,21,2,21,67,34,29,56,29,36,60,37,67,59,12,46,47,59,26,48,35,10,72,50,61,35,66,65,65,40,66,56,56,55,63,50,29,11,54,49,56,17,61,64,43,15,29,30,36,66,15,47,57,54,51,38,56,13,26,43,25,66,50,64,10,50,63,56,33,59,28,71,21,31,17,72,49,2,67,48,37,53,67,42,57,35,33,62,34,49,27,64,52,52,62,42,56,51,53,63,60,48,64,15,51,28,71,65,52,37,72,38,66,66,65,69,58,62,61,53,56,61,52,24,67,66,47,70,17,46,33,33,13,66,1,27,71,34,58,24,12,4,35,30,53,12,41,50,71,43,17,26,13,49,52,61,28,11,61,50,40,12,24,56,69,50,3,52,20,56,48,19,23,29,21,33,22,27,2,32,60,23,67,45,55,34,32,49,32,32,41,53,71,12,64,72,36,35,72,32,39,24,12,37,40,54,35,39,70,55,41,25,23,22,23,68,64,66,26,29,63,68,26,9,71,46,38,51,57,56,46,22,9,42,69,56,62,61,54,37,13,4,42,69,65,60,44,56,33,19,31,29,69,67,65,62,31,44,67,42,39,62,25,66,46,23,28,66,30,31,35,67,1,32,25,45,56,67,31,68,15,23,24,53,15,23,51,33,49,33,33,17,27,15,50,2,13,23,30,62,30,50,31,56,19,11,43,63,44,35,43,66,27,15,72,63,67,47,67,44,19,30,26,52,40,53,24,24,36,66,38,47,51,56,48,28,27,3,24,58,19,68,2,64,30,50,40,56,11,26,31,19,48,25,37,15,58,43,55,67,44,38,70,14,55,40,29,41,30,54,37,46,17,54,30,48,65,66,70,8,25,43,9,50,69,15, ...

# %% [markdown]
# ## **Tiempo de contrato vs Cancelación**

# %%
px.box(datos, x='tenure', color='Churn')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="93c5555f-ecda-4f2a-a360-c4b1a7153286" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93c5555f-ecda-4f2a-a360-c4b1a7153286")) {                    Plotly.newPlot(                        "93c5555f-ecda-4f2a-a360-c4b1a7153286",                        [{"alignmentgroup":"True","hovertemplate":"Churn=0\u003cbr\u003etenure=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa"},"name":"0","notched":false,"offsetgroup":"0","orientation":"h","showlegend":true,"x":[9,9,9,71,63,7,65,54,72,5,72,56,71,34,1,50,23,3,55,54,26,69,37,49,66,67,20,43,55,59,12,27,27,25,25,29,72,14,35,1,29,64,39,40,6,30,27,70,57,58,16,69,32,16,71,33,10,26,50,61,26,72,44,66,44,69,2,27,26,39,72,24,19,71,33,3,47,62,71,7,27,2,25,30,9,69,66,46,54,12,22,70,30,71,30,10,4,52,8,2,3,19,72,63,66,60,48,50,72,46,72,1,1,67,48,72,52,67,32,3,50,71,16,67,72,23,72,7,8,66,63,12,27,35,54,5,19,52,72,32,41,5,11,16,71,11,71,9,6,6,11,49,3,53,3,70,39,60,55,72,72,60,46,15,23,11,56,25,68,40,71,17,18,37,2,28,9,1,65,3,36,22,72,67,34,10,69,40,20,46,72,70,2,23,36,67,72,72,72,58,31,3,55,49,39,66,15,51,9,25,22,15,3,47,67,18,62,41,44,53,48,54,24,33,66,3,13,63,52,3,10,72,29,62,26,19,72,45,32,41,65,11,49,61,25,23,21,24,70,46,2,57,60,37,28,24,62,20,52,72,70,66,55,57,72,28,54,24,2,12,51,13,58,18,29,72,71,70,20,63,7,69,9,46,60,16,41,4,24,38,25,40,13,64,20,57,12,59,59,45,50,70,72,13,4,53,63,10,56,65,1,29,72,40,72,3,4,18,62,29,48,53,6,22,72,34,48,21,71,1,1,32,1,63,72,53,50,21,52,4,40,23,57,49,9,61,70,13,34,57,7,44,45,36,69,71,30,52,52,3,72,72,51,51,72,64,13,52,7,4,46,54,72,66,16,11,71,57,62,72,66,16,58,4,72,67,71,72,15,11,43,24,52,13,55,42,2,1,17,27,45,71,36,15,20,71,24,71,66,30,47,7,46,62,70,16,15,45,72,13,6,18,68,64,5,64,26,2,59,17,56,62,53,23,6,8,61,34,56,38,69,72,70,7,61,55,61,14,22,60,1,4,13,3,63,36,54,47,41,13,30,44,47,52,12,54,13,7,42,65,49,62,11,37,1,69,72,26,3,62,26,40,33,72,3,68,19,7,56,66,7,1,8,62,56,41,57,38,26,72,30,68,63,60,19,25,71,8,20,43,17,44,2,71,72,18,67,56,69,1,25,55,53,59,7,3,64,51,69,38,56,63,11,24,72,69,56,18,11,45,61,66,42,55,1,68,1,17,15,28,28,40,63,39,48,44,69,49,24,71,61,18,27,64,1,50,30,57,17,51,60,33,38,1,16,72,41,65,72,67,49,19,69,47,53,27,11,28,53,19,3,23,63,61,27,1,4,8,12,56,52,20,68,3,50,60,4,45,25,43,9,62,40,6,20,16,8,72,21,64,3,58,18,67,61,52,14,43,52,4,5,27,23,49,71,59,64,72,44,30,39,15,70,72,72,35,68,71,70,29,66,20,55,9,72,49,24,42,52,18,12,72,52,70,18,7,54,68,72,55,9,4,18,41,6,14,61,13,64,72,27,22,11,4,7,6,50,11,54,23,67,46,0,48,40,30,15,16,9,7,20,11,1,44,43,24,7,57,11,57,23,18,70,33,1,3,54,7,70,30,32,1,56,52,12,29,33,22,10,26,13,66,58,22,72,1,39,1,52,4,70,60,8,3,64,66,49,1,36,58,7,1,72,35,30,52,72,31,70,53,10,29,59,45,12,33,66,49,61,24,1,17,12,61,27,48,71,4,61,31,30,55,42,71,43,19,19,12,4,70,68,57,51,4,70,19,51,71,11,60,62,12,45,8,68,36,1,29,1,14,5,19,71,4,1,6,32,68,63,53,6,59,48,1,37,27,72,70,12,23,23,40,11,42,12,71,39,58,61,19,61,16,60,52,17,63,46,42,47,51,45,53,1,2,64,10,34,32,54,11,8,56,34,1,46,60,22,39,2,35,25,18,3,66,29,66,8,45,18,72,34,2,72,10,51,28,13,2,15,2,12,51,30,64,72,5,72,1,27,72,30,65,61,62,45,52,24,70,39,42,20,72,13,22,1,7,8,8,64,22,26,31,4,48,71,36,1,21,58,29,11,64,1,64,39,39,24,1,8,36,16,7,41,5,55,72,72,1,47,21,68,58,33,33,56,49,68,72,1,1,67,45,72,10,59,22,30,52,10,20,35,72,65,7,23,29,43,18,71,9,48,27,70,58,60,46,8,68,46,8,9,1,63,18,18,37,63,6,48,4,29,27,65,31,49,72,5,1,33,1,65,60,63,55,68,72,37,29,64,46,23,68,41,17,55,5,68,7,41,2,1,1,3,17,37,22,68,72,16,65,55,1,33,30,25,1,25,72,44,18,7,59,70,40,34,5,68,14,19,67,50,43,59,27,40,28,5,54,63,20,72,71,32,71,71,71,22,68,2,29,12,34,40,72,72,45,72,71,18,68,68,34,24,58,37,52,45,43,26,56,1,68,27,9,1,71,72,21,54,8,24,48,5,17,72,72,6,72,62,1,51,38,33,20,31,64,72,9 ...

# %% [markdown]
# ## **Distribución de Gasto total vs Cancelación**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Configurar estilo de los gráficos
sns.set(style="whitegrid")
# Definir una paleta personalizada
custom_palette = {0: "lightblue", 1: "darkred"}

# Boxplot: Gasto total vs Cancelación
plt.figure(figsize=(8, 6))
sns.boxplot(x='Churn', y='ChargesTotal', data=datos)
plt.title('Distribución de Gasto total por Cancelación')
plt.xlabel('Cancelación (0 = No, 1 = Sí)')
plt.ylabel('Gasto total (ChargesTotal)')
plt.show()

# %% [markdown]
# ## **Tiempo de contrato vs Gasto total**

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='tenure', y='ChargesTotal', hue='Churn', style='Churn', size='Churn',palette=custom_palette, data=datos)

# Personalizar la leyenda para asegurar que los colores y etiquetas sean correctos
plt.legend (title='Cancelación', labels=['No', 'Sí'],
 handles=[plt.Line2D([0], [0], marker='o', color='w',
 markerfacecolor='lightblue', markersize=10),
 plt.Line2D([0], [0], marker='X', color='w',
 markerfacecolor='darkred', markersize=10)])

plt.title('Relación entre Tiempo de contrato y Gasto total por Cancelación')
plt.xlabel('Tiempo de contrato (tenure)')
plt.ylabel('Gasto total (ChargesTotal)')
plt.show()

# %% [markdown]
# # **Tipos de modelos y su selección para el proyecto**

# %% [markdown]
# ## **Diferencias entre modelos de Regresión y Clasificación**

# %% [markdown]
# **Modelos de Regresión**
# *  **Objetivo**: Predecir valores numéricos continuos.
# *   **Ejemplos**:
#   *   Estimar el ingreso mensual de un cliente.
#   *   Calcular la duración del contrato en meses.
#   *   Proyectar las ventas futuras.
# *   **Salida**: Un valor real (y ∈ ℝ).

# %% [markdown]
# **Modelos de Clasificación**
# *   **Objetivo**: Asignar etiquetas o categorías a cada observación.
# *   **Ejemplo**:
#   *   Clasificar a un cliente como "cancelará" o "no cancelará".
# *   **Salida**: Una clase (y ∈ {0,1} en casos binarios).
# *   **Ventaja adicional**: La capacidad de entregar probabilidades asociadas a cada clase, lo que permite tomar decisiones más informadas (por ejemplo, en la segmentación de clientes en riesgo).

# %% [markdown]
# ## **Selección del modelo**

# %% [markdown]
# En este análisis, se optó por modelos de clasificación en lugar de regresión, dado que el objetivo es predecir la cancelación (Churn: Sí/No). La naturaleza binaria del problema hace que los modelos de clasificación sean la opción más adecuada.

# %% [markdown]
# # **Ajustando modelos**

# %% [markdown]
# ## **1.   Modelo de referencia**

# %% [markdown]
# El modelo más simple de clasificar los datos es simplemente utilizar un algoritmo que asigna todas las clasificaciones a la clase que tiene mayor frecuencia. Este algoritmo sirve como un criterio de comparación para identificar si los otros modelos tienen un rendimiento mejor que la clasificación más simple posible.

# %%
from sklearn.dummy import DummyClassifier

# %%
modelo_dummy = DummyClassifier()
modelo_dummy.fit(X_train, y_train)
print(f'Exactitud del modelo en el conjunto de prueba: {modelo_dummy.score(X_test, y_test):.2%}')
# Out:
# Exactitud del modelo en el conjunto de prueba: 73.37%

# %% [markdown]
# ## **2.   Árboles de decisión**

# %% [markdown]
# ### **Decision Tree**

# %% [markdown]
# Usaremos `DecisionTreeClassifier` como modelo de classificación.Se basa en decisiones simples tomadas por el algoritmo, separando los datos mediante comparaciones de menor y mayor en los valores de las columnas de la base de datos. El índice GINI calcula qué tan mezcladas están las clases. Varía de 1 a 0, dónde 0 es perfectamente separado y, 1 -completamente mezclado.

# %%
from imblearn.over_sampling import SMOTE
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_validate
from imblearn.pipeline import Pipeline as imbpipeline

# %%
modelo_arbol = DecisionTreeClassifier(max_depth=5)

# Crear pipeline
pipeline_arbol = imbpipeline(steps=[('oversample', SMOTE()), ('arbol', modelo_arbol)])
skf_arbol = StratifiedKFold(n_splits=5, shuffle=True, random_state=5)

# Validación cruzada
cv_resultados_arbol = cross_validate(pipeline_arbol, X_train, y_train, cv=skf_arbol, scoring='recall')
promedio_arbol = cv_resultados_arbol['test_score'].mean()
desvio_std_arbol = cv_resultados_arbol['test_score'].std()

# valor igual a 1 = 100% aprendizaje
print(f'Puntaje de recall en validación cruzada: {cv_resultados_arbol["test_score"]}')
print(f'Promedio recall: {promedio_arbol:.3f} (± {desvio_std_arbol:.3f})')
print(f'El intervalo de confianza aproximado: {promedio_arbol-2*desvio_std_arbol:.3f}, {min(promedio_arbol+2*desvio_std_arbol,1):.3f}')
# Out:
# Puntaje de recall en validación cruzada: [0.63909774 0.6329588  0.65413534 0.67293233 0.63157895]
# Promedio recall: 0.646 (± 0.016)
# El intervalo de confianza aproximado: 0.615, 0.677

# %%
print(nombres_columnas)
# Out:
# ['MultipleLines_No', 'MultipleLines_No phone service', 'MultipleLines_Yes', 'InternetService_DSL', 'InternetService_Fiber optic', 'InternetService_No', 'SeniorCitizen_Yes', 'OnlineSecurity_No', 'OnlineSecurity_No internet service', 'OnlineSecurity_Yes', 'OnlineBackup_No', 'OnlineBackup_No internet service', 'OnlineBackup_Yes', 'DeviceProtection_No', 'DeviceProtection_No internet service', 'DeviceProtection_Yes', 'TechSupport_No', 'TechSupport_No internet service', 'TechSupport_Yes', 'StreamingTV_No', 'StreamingTV_No internet service', 'StreamingTV_Yes', 'StreamingMovies_No', 'StreamingMovies_No internet service', 'StreamingMovies_Yes', 'Contract_Month-to-month', 'Contract_One year', 'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)', 'PaymentMethod_Credit card (automatic)', 'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check', 'PhoneService_Si', 'tenure', 'PaperlessBilling', 'ChargesMonthly', 'ChargesTotal']

# %%
valores_columnas = ['Múltiples Líneas: No', 'Múltiples Líneas: Sin servicio telefónico', 'Múltiples Líneas: Sí'
                    , 'Servicio Internet: DSL', 'Servicio Internet: Fibra óptica', 'Servicio Internet: No'
                    , 'Adulto Mayor: Sí', 'Seguridad Online: No', 'Seguridad Online: Sin servicio internet'
                    , 'Seguridad Online: Sí', 'Online Backup: No', 'OnlineBackup: Sin servicio internet'
                    , 'Online Backup: Yes', 'Protección del equipo: No', 'Protección del equipo: Sin servicio internet'
                    , 'Protección del equipo: Sí', 'Soporte técnico: No', 'Soporte técnico: Sin servicio internet'
                    , 'Soporte técnico: Sí', 'StreamingTV: No', 'StreamingTV: Sin servicio internet'
                    , 'StreamingTV: Sí', 'StreamingMovies: No', 'StreamingMovies: Sin servicio internet'
                    , 'StreamingMovies: Sí', 'Contracto mes a mes', 'Contracto anular', 'Contracto por 2 años'
                    , 'Método de pago: Transferencia (automática)', 'Método de pago: TC (automática)'
                    , 'Método de pago: Cheque electrónico', 'Método de pago: Cheque por correo'
                    , 'Servicio telefónico: Sí', 'Permanencia', 'Facturación electrónica'
                    , 'Cargos Mensuales', 'Total de Cargos']

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
# Entrenar en todo el set de entrenamiento
pipeline_arbol.fit(X_train, y_train)

# Extraer el árbol entrenado desde el pipeline
modelo_arbol_entrenado = pipeline_arbol.named_steps['arbol']

plt.figure(figsize=(15,6))
plot_tree(modelo_arbol_entrenado, feature_names=valores_columnas, filled=True
          , class_names=['no', 'si'], fontsize=7)
plt.show()

# %% [markdown]
# ### Probando el modelo Decision Tree

# %% [markdown]
# Al entrenar un modelo con la variable desbalanceada, puede ser que el patrón de los datos para la clase dominante sobresalga en relación a la clase con menor frecuencia, generando un modelo con un desempeño muy bajo para clasificar la clase de menor frecuencia.
#
# Usaremos la estrategia de oversampling que consiste en aumentar la cantidad de datos de la clase que tiene menor frecuencia hasta que tenga la misma cantidad que la clase de mayor frecuencia. De esta manera, el modelo prestará más atención al patrón de los datos de la clase que tenía menor frecuencia al principio y podrá diferenciar mejor las dos clases.

# %%
from sklearn.metrics import classification_report
# para presentar graficamente la matriz de confución
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# Evaluación en conjunto de validación (X_val, y_val)
y_arbol_previsto = pipeline_arbol.predict(X_val)

print("\n=== Evaluación en conjunto de validación del modelo Decision Tree ===")
print(classification_report(y_val, y_arbol_previsto, target_names=['no', 'si']))
# en el eje Y van los valores reales y (1 -evadido, 0 -permanece) en el eje X los valores previstos
ConfusionMatrixDisplay.from_predictions(y_val, y_arbol_previsto, display_labels=['no','si']);
# Out:
# === Evaluación en conjunto de validación del modelo Decision Tree ===
#               precision    recall  f1-score   support
#
#           no       0.88      0.76      0.82      1229
#           si       0.52      0.72      0.60       444
#
#     accuracy                           0.75      1673
#    macro avg       0.70      0.74      0.71      1673
# weighted avg       0.79      0.75      0.76      1673

# %% [markdown]
# ### **Random Forest**

# %% [markdown]
# Utilizaremos el algoritmo `Random Forest` para crear un modelo y evaluar el desempeño con la precisión y la matriz de confusión, y comparar los resultados con el resultado del árbol de decisión.

# %%
from sklearn.ensemble import RandomForestClassifier
from imblearn.pipeline import Pipeline as imbpipeline
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import StratifiedKFold, cross_validate

# %%
# Modelo base
modelo_forest = RandomForestClassifier(
    n_estimators=200,  # cantidad de árboles
    max_depth=5,       # profundidad máxima
    random_state=5,
    n_jobs=-1,         # usar todos los núcleos disponibles
    class_weight="balanced"
)

# Crear pipeline
pipeline_forest = imbpipeline(steps=[
      ('oversample', SMOTE(random_state=5)),
    #, ('feature_selection', SelectFromModel(modelo_forest, threshold="median"))  # Selección automática
      ('forest', modelo_forest)
])

# Validación cruzada
skf_forest = StratifiedKFold(n_splits=5, shuffle=True, random_state=5)
cv_resultados_forest = cross_validate(
    pipeline_forest, X_train, y_train,
    cv=skf_forest, scoring='recall'
)

promedio_forest = cv_resultados_forest['test_score'].mean()
desvio_std_forest = cv_resultados_forest['test_score'].std()

# valor igual a 1 = 100% aprendizaje
print(f'Puntaje de recall en validación cruzada: {cv_resultados_forest["test_score"]}')
print(f'Promedio recall: {promedio_forest:.3f} (± {desvio_std_forest:.3f})')
print(f'El intervalo de confianza aproximado: {promedio_forest-2*desvio_std_forest:.3f}, {min(promedio_forest+2*desvio_std_forest,1):.3f}')
# Out:
# Puntaje de recall en validación cruzada: [0.73684211 0.73033708 0.69924812 0.70300752 0.67293233]
# Promedio recall: 0.708 (± 0.023)
# El intervalo de confianza aproximado: 0.662, 0.755

# %% [markdown]
# ### **Probando el modelo Random Forest**

# %%
# para presentar graficamente la matriz de confución
import matplotlib.pyplot as plt
from sklearn.metrics import (
    confusion_matrix, classification_report, ConfusionMatrixDisplay,
)

# %%
# Entrenar en todo el set de entrenamiento
pipeline_forest.fit(X_train, y_train)

# Evaluación en conjunto de validación
y_forest_previsto = pipeline_forest.predict(X_val)

print("\n=== Evaluación en conjunto de validación del modelo Random Forest ===")
print(confusion_matrix(y_val, y_forest_previsto))
print(classification_report(y_val, y_forest_previsto, target_names=['no', 'si']))

ConfusionMatrixDisplay.from_predictions(y_val, y_forest_previsto, display_labels=['no','si'])
plt.show()
# Out:
# === Evaluación en conjunto de validación del modelo Random Forest ===
# [[950 279]
#  [124 320]]
#               precision    recall  f1-score   support
#
#           no       0.88      0.77      0.83      1229
#           si       0.53      0.72      0.61       444
#
#     accuracy                           0.76      1673
#    macro avg       0.71      0.75      0.72      1673
# weighted avg       0.79      0.76      0.77      1673

# %% [markdown]
# ## **3.   Modelos basados en distancia**

# %% [markdown]
# Modelos basados en distancia, como **KNN**, **SVM**, **Regresión Logística** y **Redes Neuronales**, requieren realizar una transformación en los datos. Por otro lado, modelos basados en árboles, como **Decision Tree**, **Random Forest** y **XGBoost**, no son sensibles a la escala de los datos.

# %% [markdown]
# ### **KNN (k-Nearest Neighbors)**

# %% [markdown]
# El algoritmo KNN se basa en el cálculo de la distancia entre los registros de la base de datos y busca elementos que estén cerca unos de otros (vecinos) para tomar la decisión de clasificación.
#
# Debido a que utiliza cálculos de distancia, este algoritmo está influenciado por la escala de las variables, y por eso es necesario realizar una transformación en los datos antes de utilizar este método.

# %%
from imblearn.pipeline import Pipeline as imbpipeline
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.neighbors import KNeighborsClassifier

# %%
# Definir modelo
modelo_knn = KNeighborsClassifier()

# Crear pipeline con normalización incluida
pipeline_knn = imbpipeline(steps=[
    ('oversample', SMOTE(random_state=5)),
    ('normalizacion', MinMaxScaler()),
    ('knn', modelo_knn)
])

# Validación cruzada
skf_knn = StratifiedKFold(n_splits=5, shuffle=True, random_state=5)
cv_resultados_knn = cross_validate(pipeline_knn, X_train, y_train, cv=skf_knn, scoring='recall')

# Resultados
promedio_knn = cv_resultados_knn['test_score'].mean()
desvio_std_knn = cv_resultados_knn['test_score'].std()

# valor igual a 1 = 100% aprendizaje
print(f'Puntaje de recall en validación cruzada: {cv_resultados_knn["test_score"]}')
print(f'Promedio recall: {promedio_forest:.3f} (± {desvio_std_knn:.3f})')
print(f'El intervalo de confianza aproximado: {promedio_knn-2*desvio_std_knn:.3f}, {min(promedio_knn+2*desvio_std_knn,1):.3f}')
# Out:
# Puntaje de recall en validación cruzada: [0.67669173 0.70786517 0.66917293 0.71052632 0.68045113]
# Promedio recall: 0.708 (± 0.017)
# El intervalo de confianza aproximado: 0.655, 0.723

# %% [markdown]
# ### **Probando el modelo KNN**

# %%
from sklearn.metrics import classification_report
# para presentar graficamente la matriz de confución
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# Entrenar en todo el set de entrenamiento
pipeline_knn.fit(X_train, y_train)

# Evaluación en conjunto de validación (X_val, y_val)
y_knn_previsto = pipeline_knn.predict(X_val)

print("\n=== Evaluación en conjunto de validación del modelo KNN ===")
print(classification_report(y_val, y_knn_previsto, target_names=['no', 'si']))
# en el eje Y van los valores reales y (1 -evadido, 0 -permanece) en el eje X los valores previstos
ConfusionMatrixDisplay.from_predictions(y_val, y_knn_previsto, display_labels=['no','si']);
# Out:
# === Evaluación en conjunto de validación del modelo KNN ===
#               precision    recall  f1-score   support
#
#           no       0.86      0.72      0.78      1229
#           si       0.46      0.66      0.54       444
#
#     accuracy                           0.70      1673
#    macro avg       0.66      0.69      0.66      1673
# weighted avg       0.75      0.70      0.72      1673

# %% [markdown]
# # **Informes de métricas**

# %%
from sklearn.metrics import (
    roc_curve, roc_auc_score, precision_recall_curve, average_precision_score
)

# %%
# Probabilidades predichas
y_proba_arbol = pipeline_arbol.predict_proba(X_val)[:,1]
y_proba_forest = pipeline_forest.predict_proba(X_val)[:,1]
y_proba_knn = pipeline_knn.predict_proba(X_val)[:,1]

# %% [markdown]
# ## **Curva ROC**

# %%
fpr_arbol, tpr_arbol, _ = roc_curve(y_val, y_proba_arbol)
roc_auc_arbol = roc_auc_score(y_val, y_proba_arbol)

fpr_forest, tpr_forest, _forest = roc_curve(y_val, y_proba_forest)
roc_auc_forest = roc_auc_score(y_val, y_proba_forest)

fpr_knn, tpr_knn, _knn = roc_curve(y_val, y_proba_knn)
roc_auc_knn = roc_auc_score(y_val, y_proba_knn)

plt.plot(fpr_arbol, tpr_arbol, label=f'DecisionTree (AUC = {roc_auc_arbol:.2f})')
plt.plot(fpr_forest, tpr_forest, label=f'RandomForest (AUC = {roc_auc_forest:.2f})')
plt.plot(fpr_knn, tpr_knn, label=f'KNN (AUC = {roc_auc_knn:.2f})')
plt.plot([0,1],[0,1],'--',color='gray')
plt.xlabel("Tasa de Falsos Positivos")
plt.ylabel("Tasa de Verdaderos Positivos")
plt.title("Curva ROC")
plt.legend()
plt.show()

# %% [markdown]
# ## **Curva Precision-Recall**

# %%
prec_arbol, rec_arbol, _arbol = precision_recall_curve(y_val, y_proba_arbol)
ap_arbol = average_precision_score(y_val, y_proba_arbol)

prec_forest, rec_forest, _forest = precision_recall_curve(y_val, y_proba_forest)
ap_forest = average_precision_score(y_val, y_proba_forest)

prec_knn, rec_knn, _knn = precision_recall_curve(y_val, y_proba_knn)
ap_knn = average_precision_score(y_val, y_proba_knn)

plt.plot(rec_arbol, prec_arbol, label=f'DecisionTree = {ap_arbol:.2f}')
plt.plot(rec_forest, prec_forest, label=f'RandomForest = {ap_forest:.2f}')
plt.plot(rec_knn, prec_knn, label=f'KNN = {ap_knn:.2f}')
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Curva Precision-Recall")
plt.legend()
plt.show()

# %% [markdown]
# ## **Comparación de curvas ROC entre modelos**

# %%
from sklearn.metrics import RocCurveDisplay
import matplotlib.pyplot as plt

# Crear figura y eje
fig, ax = plt.subplots(figsize=(8, 6))

# Dibujar cada curva ROC
RocCurveDisplay.from_predictions(y_val, y_forest_previsto
                                 , ax=ax, color='blue'
                                 , name='Arbol de decisión de modelo FOREST')
RocCurveDisplay.from_predictions(y_val, y_arbol_previsto
                                 , ax=ax, linestyle='--', color='green'
                                 , name='Arbol de decisión de modelo TREE')#, ax = curva_roc.ax_)
RocCurveDisplay.from_predictions(y_val, y_knn_previsto
                                 , ax=ax, linestyle='-.', color='pink'
                                 , name='Modelo KNN') #, ax = curva_roc.ax_)

# Títulos
ax.set_title("Comparación de curvas ROC\nmodelo Forest vs Decision Tree")
plt.show()

# %% [markdown]
# # **Feature importances (atributos más importantes del modelo)**

# %% [markdown]
# Vamos a evaluar cuales son y cuantas columnas necesitamos para entrenar el modelo, segun como estas afectan a las metricas.

# %%
importances = modelo_forest.feature_importances_

# %%
feature_importances = pd.DataFrame({"Features": X.columns, "Importances": (importances*100).round(2)}).sort_values("Importances", ascending=False)
feature_importances
# Out:
#                                    Features  Importances
# 25                  Contract_Month-to-month        19.67
# 30           PaymentMethod_Electronic check        11.17
# 16                           TechSupport_No        10.74
# 7                         OnlineSecurity_No         8.83
# 33                                   tenure         6.50
# 10                          OnlineBackup_No         6.05
# 27                        Contract_Two year         4.68
# 9                        OnlineSecurity_Yes         4.15
# 18                          TechSupport_Yes         3.64
# 13                      DeviceProtection_No         3.04
# 26                        Contract_One year         2.83
# 36                             ChargesTotal         2.75
# 34                         PaperlessBilling         2.50
# 4               InternetService_Fiber optic         2.44
# 12                         OnlineBackup_Yes         1.83
# 17          TechSupport_No internet service         1.03
# 35                           ChargesMonthly         0.85
# 11         OnlineBackup_No internet service         0.78
# 23      StreamingMovies_No internet service         0.66
# 3                       InternetService_DSL         0.63
# 29    PaymentMethod_Credit card (automatic)         0.62
# 28  PaymentMethod_Bank transfer (automatic)         0.56
# 6                         SeniorCitizen_Yes         0.54
# 14     DeviceProtection_No internet service         0.51
# 20          StreamingTV_No internet service         0.45
# 5                        InternetService_No         0.41
# 31               PaymentMethod_Mailed check         0.33
# 22                       StreamingMovies_No         0.28
# 24                      StreamingMovies_Yes         0.26
# 8        OnlineSecurity_No internet service         0.25
# 15                     DeviceProtection_Yes         0.23
# 21                          StreamingTV_Yes         0.20
# 0                          MultipleLines_No         0.18
# 19                           StreamingTV_No         0.18
# 2                         MultipleLines_Yes         0.16
# 1            MultipleLines_No phone service         0.05
# 32                          PhoneService_Si         0.03

# %%
selected_features = feature_importances['Features'].values[:15]
X_selected_features = X[selected_features]

X_selected_features
# Out:
#       Contract_Month-to-month  PaymentMethod_Electronic check  TechSupport_No  \
# 1448                      0.0                             0.0             0.0
# 343                       0.0                             0.0             0.0
# 3500                      0.0                             0.0             0.0
# 2932                      0.0                             0.0             0.0
# 67                        0.0                             1.0             0.0
# ...                       ...                             ...             ...
# 6889                      0.0                             0.0             0.0
# 2936                      0.0                             0.0             1.0
# 2846                      1.0                             0.0             1.0
# 6661                      0.0                             0.0             1.0
# 5161                      1.0                             1.0             1.0
#
#       OnlineSecurity_No  tenure  OnlineBackup_No  Contract_Two year  \
# 1448                0.0    14.0              0.0                1.0
# 343                 0.0    57.0              0.0                1.0
# 3500                0.0    15.0              0.0                0.0
# 2932                1.0    36.0              0.0                0.0
# 67                  0.0    49.0              1.0                0.0
# ...                 ...     ...              ...                ...
# 6889                0.0    35.0              0.0                1.0
# 2936                1.0    26.0              1.0                0.0
# 2846                1.0     3.0              1.0                0.0
# 6661                0.0    70.0              0.0                1.0
# 5161                1.0     1.0              1.0                0.0
#
#       OnlineSecurity_Yes  TechSupport_Yes  DeviceProtection_No  \
# 1448                 0.0              0.0                  0.0
# 343                  0.0              0.0                  0.0
# 3500                 1.0              1.0                  0.0
# 2932                 0.0              1.0                  1.0
# 67                   1.0              1.0                  0.0
# ...                  ...              ...                  ...
# 6889                 1.0              1.0                  0.0
# 2936                 0.0              0.0                  1.0
# 2846                 0.0              0.0                  1.0
# 6661                 1.0              0.0                  0.0
# 5161                 0.0              0.0                  1.0
#
#       Contract_One year  ChargesTotal  PaperlessBilling  \
# 1448                0.0        263.65               1.0
# 343                 0.0       1087.70               1.0
# 3500                1.0       1010.00               0.0
# 2932                1.0       2511.95               1.0
# 67                  1.0       4059.35               0.0
# ...                 ...           ...               ...
# 6889                0.0       3914.05               1.0
# 2936                1.0       1295.40               1.0
# 2846                0.0        141.70               0.0
# 6661                0.0       5600.15               1.0
# 5161                0.0         69.65               1.0
#
#       InternetService_Fiber optic  OnlineBackup_Yes
# 1448                          0.0               0.0
# 343                           0.0               0.0
# 3500                          0.0               1.0
# 2932                          0.0               1.0
# 67                            0.0               0.0
# ...                           ...               ...
# 6889                          1.0               1.0
# 2936                          0.0               0.0
# 2846                          0.0               0.0
# 6661                          0.0               1.0
# 5161                          1.0               0.0
#
# [6690 rows x 15 columns]

# %%
X_train_grid, X_test_grid, y_train_grid, y_test_grid = train_test_split(X_selected_features, y, random_state=5)

# %%
param_grid = {
    'forest__max_depth': [5, 10, 15],
    'forest__n_estimators': [100, 200, 300],
    'forest__class_weight': [None, 'balanced']
}

# %%
from sklearn.model_selection import GridSearchCV

# Modelo base
modelo = RandomForestClassifier(
    random_state=5,
    n_jobs=-1,         # usar todos los núcleos disponibles
)

# Crear pipeline
pipeline = imbpipeline(steps=[
      ('oversample', SMOTE(random_state=5)),
      ('forest', modelo)
])

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=5)
model_grid = GridSearchCV(pipeline, param_grid=param_grid, cv=cv, scoring='recall', n_jobs=-1)
model_grid.fit(X_train_grid, y_train_grid)

print("Mejores parámetros:", model_grid.best_params_)
print("Mejor recall en CV:", model_grid.best_score_)
# Out:
# Mejores parámetros: {'forest__class_weight': None, 'forest__max_depth': 5, 'forest__n_estimators': 200}
# Mejor recall en CV: 0.7003745318352059

# %%
from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score, classification_report

def calcular_metricas(y_test, y_pred):
    # Calcular métricas
    metricas = {
        'recall': recall_score(y_test, y_pred),
        'precision': precision_score(y_test, y_pred),
        'f1_score': f1_score(y_test, y_pred),
        'accuracy': accuracy_score(y_test, y_pred)
    }

    # Imprimir reporte de clasificación detallado
    print("Reporte de clasificación:")
    print(classification_report(y_test, y_pred, target_names=['No', 'Sí']))

    return metricas

# %%
y_pred_grid = model_grid.predict(X_test_grid)
metricas_model_grid = calcular_metricas(y_test_grid, y_pred_grid)
print('Métricas del modelo grid:', metricas_model_grid)
# Out:
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#           No       0.88      0.80      0.84      1233
#           Sí       0.55      0.70      0.61       440
#
#     accuracy                           0.77      1673
#    macro avg       0.72      0.75      0.73      1673
# weighted avg       0.79      0.77      0.78      1673
#
# Métricas del modelo grid: {'recall': 0.6954545454545454, 'precision': 0.5503597122302158, 'f1_score': 0.6144578313253012, 'accuracy': 0.7704722056186492}

# %% [markdown]
# # **Escogiendo y serializando el mejor modelo**

# %% [markdown]
# ### **Evaluamos la tasa de acierto de los modelos**

# %%
lista_modelos = [
    ('dummy', modelo_dummy, X_test),
    ('arbol', modelo_arbol, X_test),
    ('random forest', modelo_forest, X_test),
    ('knn', pipeline_knn, X_test)
]

# %%
for nombre, modelo, X in lista_modelos:
    print(f'La exactidud del modelo {nombre} es: {modelo.score(X, y_test)}')
# Out:
# La exactidud del modelo dummy es: 0.7337110481586402
# La exactidud del modelo arbol es: 0.7450424929178471
# La exactidud del modelo random forest es: 0.7620396600566572
# La exactidud del modelo knn es: 0.7110481586402266

# %% [markdown]
# ## **Serializando los modelos**

# %%
# almacena el modelo con mejor precisión en un archivo
import joblib

# %%
# exportar el modelo entrenado a un archivo
joblib.dump(modelo_forest, 'modelo_churn_forest_II.pkl')
joblib.dump(modelo_arbol, 'modelo_churn_arbol_champion.pkl')
joblib.dump(modelo_knn, 'modelo_churn_knn_IV.pkl')
joblib.dump(modelo_dummy, 'modelo_churn_dummy_III.pkl')
# Out:
# ['modelo_churn_dummy_III.pkl']

# %% [markdown]
# # **Conclusión**

# %% [markdown]
# ## Modelos de Clasificación evaluados

# %% [markdown]
# Se probaron distintos algoritmos para comparar su rendimiento en la predicción de cancelación de clientes:
#
# - **Dummy Classifier**: modelo base para tener un punto de referencia (baseline).
# - **Árbol de Decisión**: fácil de interpretar, permite identificar reglas claras de decisión.
# - **Random Forest**: modelo de ensamble, mejora la estabilidad y el rendimiento respecto a un único árbol.
# - **KNN (K-Nearest Neighbors)**: requiere normalización de datos, evalúa similitudes entre clientes.
#
# La métrica principal utilizada fue **recall**, ya que el interés está en **detectar la mayor cantidad de clientes que cancelan** (minimizando falsos negativos).

# %% [markdown]
# ## Comparación de modelos

# %% [markdown]
# Los resultados obtenidos muestran que:
#
# - **Random Forest** logró el mejor equilibrio entre precisión y recall. Su capacidad de ensamble le permite capturar relaciones no lineales y reducir el sobreajuste. Es el mejor modelo para predecir la cancelación de clientes.
# - El **Árbol de Decisión** fue útil para interpretar factores de riesgo, pero tuvo menor estabilidad y recall que Random Forest.
# - El **KNN**, aunque normalizado, no alcanzó el rendimiento esperado, probablemente por la dimensionalidad y dispersión de los datos.
# - El **Dummy Classifier** confirma que los demás modelos superan el rendimiento de la simple predicción aleatoria.
#
# En resumen, el **Random Forest** es el mejor modelo para este caso, alcanzando un **AUC de 0.83** y un **Average Precision (AP) de 0.61**, lo que indica un buen desempeño para la detección de clientes en riesgo.

# %% [markdown]
# ## Análisis de curvas

# %% [markdown]
# ### Curva Precision-Recall

# %% [markdown]
# - La **precisión promedio es de 0.61**, lo que significa que, al clasificar clientes como en riesgo de cancelar, el 61% efectivamente cancela.
# - El comportamiento decreciente de la curva refleja que, a medida que se busca capturar más clientes (mayor recall), disminuye la precisión.
# - Esto indica un **trade-off**: se debe balancear entre captar la mayoría de clientes que cancelan (recall) y evitar falsos positivos.

# %% [markdown]
# ### Curva ROC

# %% [markdown]
# - El **AUC de 0.83** confirma que el modelo distingue bien entre clientes que cancelan y los que no.
# - La curva está muy por encima de la diagonal aleatoria, lo que valida el buen rendimiento del Random Forest.

# %% [markdown]
# ---
#
# ## Principales factores que influyen en la cancelación

# %% [markdown]
# Según las variables seleccionadas y los resultados del modelo, los factores más relevantes fueron:
#
# - **Duración del contrato**: los clientes con contratos de corto plazo presentan mayor probabilidad de cancelar.
# - **Uso de servicios adicionales**: quienes no contratan servicios extra (internet, TV, paquetes premium) muestran mayor tasa de abandono.
# - **Nivel de facturación mensual**: cuentas con cobros elevados tienen más riesgo de cancelación.
# - **Experiencia del cliente**: un alto número de reclamos o llamadas se asocia con mayor churn.
# - **Forma de pago**: clientes que usan métodos menos automáticos (ej. cheque electrónico) tienden a cancelar más.

# %% [markdown]
# ## Estrategias de retención

# %% [markdown]
# Con base en los resultados, se recomiendan las siguientes acciones:
#
# 1. **Incentivar contratos a largo plazo**: ofrecer descuentos o beneficios por permanencia mínima.
# 2. **Promocionar servicios adicionales**: paquetes personalizados que aumenten la satisfacción y dependencia del cliente.
# 3. **Revisar política de precios**: segmentar promociones para clientes de alta facturación y riesgo.
# 4. **Mejorar la atención al cliente**: programas de fidelización y respuestas rápidas a reclamos.
# 5. **Facilitar pagos automáticos**: incentivar a los clientes a migrar a métodos de débito automático o tarjetas.

# %% [markdown]
# # Task
# Complete the telecom churn prediction project by performing the following steps:
#
# 1.  **Efficient Data Loading and Cleaning**: Load the dataset from "https://raw.githubusercontent.com/Bufudyne/Telecom-Parte-2/refs/heads/master/datos_churn_filtrados.csv" and immediately drop irrelevant or redundant columns such as `customerID`, `gender`, `Partner`, `Dependents`, `Cuentas_Diarias`, `tenure_interval`, `TotalPayed`, and `TotalPayed_interval`.
# 2.  **Preprocessing and Encoding**: Revert encoded values back to readable categorical labels. Apply `OneHotEncoder` with `drop='if_binary'` to transform categorical variables. Split the data into training, validation, and test sets (70/25/5 ratio) ensuring stratification of the target variable (`Churn`).
# 3.  **Targeted Exploratory Analysis**: Generate key visualizations (Boxplots and Scatterplots) relating `tenure` and `ChargesTotal` with `Churn` to validate business hypotheses.
# 4.  **Competitive Model Training**: Implement a cross-validation pipeline comparing **Decision Tree**, **Random Forest**, and **KNN**. Use **SMOTE** within the pipeline to balance the minority class, focusing on the **Recall** metric.
# 5.  **Optimization and Feature Importance**: Conduct a hyperparameter search using `GridSearchCV` for the Random Forest model and extract feature importance to identify the primary drivers of customer cancellation.
# 6.  **Executive Conclusions and Serialization**: Summarize technical findings focusing on actionable insights and final performance metrics (AUC, Recall). Export the trained models using `joblib`.
# 7.  **Final Task**: Summarize the analysis results and confirm the successful execution of all project stages.

# %% [markdown]
# ## Carga y Limpieza Eficiente
#
# ### Subtask:
# Cargar el conjunto de datos desde la URL proporcionada y eliminar las columnas irrelevantes para optimizar el análisis.

# %% [markdown]
# **Reasoning**:
# Load the dataset from the provided URL and drop the specified irrelevant columns to streamline the dataframe for analysis.

# %%
import pandas as pd

# Define the URL and load the dataset
URL = 'https://raw.githubusercontent.com/Bufudyne/Telecom-Parte-2/refs/heads/master/datos_churn_filtrados.csv'
datos = pd.read_csv(URL)

# List of columns to drop
columns_to_drop = [
    'customerID', 'gender', 'Partner', 'Dependents',
    'Cuentas_Diarias', 'tenure_interval', 'TotalPayed', 'TotalPayed_interval'
]

# Drop irrelevant columns
datos = datos.drop(columns=columns_to_drop)

# Display the first few rows and the remaining columns
print('Columnas restantes:', datos.columns.tolist())
display(datos.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_579/714520417.py in <cell line: 0>()
#      12
#      13 # Drop irrelevant columns
# ---> 14 datos = datos.drop(columns=columns_to_drop)
#      15
#      16 # Display the first few rows and the remaining columns
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['tenure_interval', 'TotalPayed', 'TotalPayed_interval'] not found in axis"

# %% [markdown]
# **Reasoning**:
# The previous code failed because some columns in the drop list ('tenure_interval', 'TotalPayed', 'TotalPayed_interval') were not found in the CSV. I will modify the drop command to include errors='ignore' so that it only removes columns that actually exist in the loaded dataframe, ensuring the script completes successfully.

# %%
import pandas as pd

# Define the URL and load the dataset
URL = 'https://raw.githubusercontent.com/Bufudyne/Telecom-Parte-2/refs/heads/master/datos_churn_filtrados.csv'
datos = pd.read_csv(URL)

# List of columns to drop as requested in instructions
columns_to_drop = [
    'customerID', 'gender', 'Partner', 'Dependents',
    'Cuentas_Diarias', 'tenure_interval', 'TotalPayed', 'TotalPayed_interval'
]

# Drop irrelevant columns, using errors='ignore' to avoid failure if some specific columns are missing
datos = datos.drop(columns=columns_to_drop, errors='ignore')

# Display the first few rows and the remaining columns
print('Columnas restantes:', datos.columns.tolist())
display(datos.head())
# Out:
# Columnas restantes: ['Churn', 'SeniorCitizen', 'tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'ChargesMonthly', 'ChargesTotal']
#    Churn  SeniorCitizen  tenure PhoneService MultipleLines InternetService  \
# 0      0              0       9          Yes            No             DSL
# 1      0              0       9          Yes           Yes             DSL
# 2      1              0       4          Yes            No     Fiber optic
# 3      1              1      13          Yes            No     Fiber optic
# 4      1              1       3          Yes            No     Fiber optic
#
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0             No          Yes               No         Yes         Yes
# 1             No           No               No          No          No
# 2             No           No              Yes          No          No
# 3             No          Yes              Yes          No         Yes
# 4             No           No               No         Yes         Yes
#
#   StreamingMovies  Contract PaperlessBilling  PaymentMethod  ChargesMonthly  \
# 0              No         1              Yes              1            65.6
# 1             Yes         0               No              1            59.9
# 2              No         0              Yes              0            73.9
# 3             Yes         0              Yes              0            98.0
# 4              No         0              Yes              1            83.9
#
#    ChargesTotal
# 0        593.30
# 1        542.40
# 2        280.85
# 3       1237.85
# 4        267.40

# %% [markdown]
# ## Preprocesamiento y Codificación
#
# ### Subtask:
# Revertir valores a categorías legibles, aplicar OneHotEncoder y dividir los datos en conjuntos de entrenamiento, validación y prueba.

# %% [markdown]
# **Reasoning**:
# I will perform the mapping of numerical values to categorical labels, apply OneHotEncoder using ColumnTransformer, and execute the stratified split into training, validation, and test sets as instructed.

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
import pandas as pd

# 1. Map values back to readable categories
datos['MultipleLines'] = datos['MultipleLines'].map({0:'No', 1:'Yes', -1:'No phone service'})
datos['InternetService'] = datos['InternetService'].map({0:'DSL', 1:'Fiber optic', -1:'No'})
datos['SeniorCitizen'] = datos['SeniorCitizen'].map({0:'No', 1:'Yes'})
datos['OnlineSecurity'] = datos['OnlineSecurity'].map({0:'No', 1:'Yes', -1:'No internet service'})
datos['OnlineBackup'] = datos['OnlineBackup'].map({0:'No', 1:'Yes', -1:'No internet service'})
datos['DeviceProtection'] = datos['DeviceProtection'].map({0:'No', 1:'Yes', -1:'No internet service'})
datos['TechSupport'] = datos['TechSupport'].map({0:'No', 1:'Yes', -1:'No internet service'})
datos['StreamingTV'] = datos['StreamingTV'].map({0:'No', 1:'Yes', -1:'No internet service'})
datos['StreamingMovies'] = datos['StreamingMovies'].map({0:'No', 1:'Yes', -1:'No internet service'})
datos['Contract'] = datos['Contract'].map({0:'Month-to-month', 1:'One year', 2:'Two year'})
datos['PaymentMethod'] = datos['PaymentMethod'].map({0:'Electronic check', 1:'Mailed check', 2:'Bank transfer (automatic)', 3:'Credit card (automatic)'})
datos['PhoneService'] = datos['PhoneService'].map({0:'No', 1:'Yes'})
datos['PaperlessBilling'] = datos['PaperlessBilling'].map({0:'No', 1:'Yes'})

# 2. Define X and y
X = datos.drop('Churn', axis=1)
y = datos['Churn']

# 3. Setup ColumnTransformer and OneHotEncoder
categorical_cols = ['MultipleLines', 'InternetService', 'SeniorCitizen', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaymentMethod', 'PhoneService', 'PaperlessBilling']
ohe = OneHotEncoder(drop='if_binary', sparse_output=False)
ct = ColumnTransformer(transformers=[('ohe', ohe, categorical_cols)], remainder='passthrough')

# 4. Transform X and reconstruct DataFrame
X_transformed = ct.fit_transform(X)
feature_names = [name.split('__')[-1] for name in ct.get_feature_names_out()]
X = pd.DataFrame(X_transformed, columns=feature_names)

# 5. Stratified Split (70/25/5)
# First split: Separate 5% for test
X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=0.05, stratify=y, random_state=5)
# Second split: Separate 25% of the original data (which is ~26.3% of the remaining 95%) for validation
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.25/0.95, stratify=y_temp, random_state=5)

print(f'Train shape: {X_train.shape}, Val shape: {X_val.shape}, Test shape: {X_test.shape}')
print('Preprocessing and splitting completed.')
# Out:
# Train shape: (4929, 21), Val shape: (1761, 21), Test shape: (353, 21)
# Preprocessing and splitting completed.

# %% [markdown]
# ## Análisis Exploratorio Dirigido
#
# ### Subtask:
# Generar visualizaciones clave (Boxplots y Scatterplots) que relacionen la permanencia (tenure) y los cargos totales con el Churn para validar hipótesis de negocio.

# %% [markdown]
# **Reasoning**:
# I will import the necessary visualization libraries and create the requested boxplots and scatterplot to analyze the relationship between tenure, ChargesTotal, and Churn.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the aesthetic style of the plots
sns.set_theme(style="whitegrid")

# Create a figure with subplots
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# 1. Boxplot: Tenure vs Churn
sns.boxplot(data=datos, x='Churn', y='tenure', ax=axes[0], palette='Set2')
axes[0].set_title('Distribución de Permanencia (Tenure) por Churn')
axes[0].set_xlabel('Churn (0: No, 1: Sí)')
axes[0].set_ylabel('Meses de Permanencia')

# 2. Boxplot: ChargesTotal vs Churn
sns.boxplot(data=datos, x='Churn', y='ChargesTotal', ax=axes[1], palette='Set1')
axes[1].set_title('Distribución de Cargos Totales por Churn')
axes[1].set_xlabel('Churn (0: No, 1: Sí)')
axes[1].set_ylabel('Cargos Totales ($)')

plt.tight_layout()
plt.show()

# 3. Scatterplot: Tenure vs ChargesTotal colored by Churn
plt.figure(figsize=(10, 7))
sns.scatterplot(data=datos, x='tenure', y='ChargesTotal', hue='Churn', style='Churn', alpha=0.6, palette='viridis')
plt.title('Relación entre Permanencia y Cargos Totales por Churn')
plt.xlabel('Meses de Permanencia (Tenure)')
plt.ylabel('Cargos Totales ($)')
plt.legend(title='Churn', labels=['No (0)', 'Sí (1)'])
plt.show()
# Out:
# /tmp/ipykernel_579/3847246026.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=datos, x='Churn', y='tenure', ax=axes[0], palette='Set2')
# /tmp/ipykernel_579/3847246026.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=datos, x='Churn', y='ChargesTotal', ax=axes[1], palette='Set1')

# %% [markdown]
# **Reasoning**:
# The previous code execution triggered FutureWarnings because `palette` was used without assigning `hue` in `sns.boxplot`. I will update the code to assign `hue='Churn'` and set `legend=False` to comply with the latest Seaborn API and ensure a clean output.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the aesthetic style of the plots
sns.set_theme(style="whitegrid")

# Create a figure with subplots
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# 1. Boxplot: Tenure vs Churn - Fixed FutureWarnings by assigning hue
sns.boxplot(data=datos, x='Churn', y='tenure', ax=axes[0], palette='Set2', hue='Churn', legend=False)
axes[0].set_title('Distribución de Permanencia (Tenure) por Churn')
axes[0].set_xlabel('Churn (0: No, 1: Sí)')
axes[0].set_ylabel('Meses de Permanencia')

# 2. Boxplot: ChargesTotal vs Churn - Fixed FutureWarnings by assigning hue
sns.boxplot(data=datos, x='Churn', y='ChargesTotal', ax=axes[1], palette='Set1', hue='Churn', legend=False)
axes[1].set_title('Distribución de Cargos Totales por Churn')
axes[1].set_xlabel('Churn (0: No, 1: Sí)')
axes[1].set_ylabel('Cargos Totales ($)')

plt.tight_layout()
plt.show()

# 3. Scatterplot: Tenure vs ChargesTotal colored by Churn
plt.figure(figsize=(10, 7))
sns.scatterplot(data=datos, x='tenure', y='ChargesTotal', hue='Churn', style='Churn', alpha=0.6, palette='viridis')
plt.title('Relación entre Permanencia y Cargos Totales por Churn')
plt.xlabel('Meses de Permanencia (Tenure)')
plt.ylabel('Cargos Totales ($)')
plt.legend(title='Churn', labels=['No (0)', 'Sí (1)'])
plt.show()

# %% [markdown]
# ## Entrenamiento de Modelos Competitivos
#
# ### Subtask:
# Ejecutar una validación cruzada comparando Decision Tree, Random Forest y KNN utilizando SMOTE para balancear la clase minoritaria, con foco en la métrica Recall.

# %% [markdown]
# **Reasoning**:
# I will implement a cross-validation loop to evaluate Decision Tree, Random Forest, and KNN models using a SMOTE-enabled pipeline to handle class imbalance, focusing on the Recall metric.

# %%
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as imbpipeline
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold, cross_validate
import numpy as np

# 1. Define base models with random_state for reproducibility
models = [
    ('Decision Tree', DecisionTreeClassifier(random_state=5)),
    ('Random Forest', RandomForestClassifier(n_estimators=100, random_state=5, n_jobs=-1)),
    ('KNN', KNeighborsClassifier())
]

# 2. Setup StratifiedKFold cross-validation
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=5)

# 3. Iterate through models, build pipelines with SMOTE, and evaluate
results = {}

print('Iniciando validación cruzada con SMOTE (Métrica: Recall)...\n')

for name, model in models:
    # Create pipeline: SMOTE -> Model
    pipeline = imbpipeline(steps=[
        ('oversample', SMOTE(random_state=5)),
        ('classifier', model)
    ])

    # Run cross_validate
    cv_results = cross_validate(
        pipeline, X_train, y_train,
        cv=skf,
        scoring='recall',
        n_jobs=-1
    )

    mean_recall = cv_results['test_score'].mean()
    std_recall = cv_results['test_score'].std()
    results[name] = {'mean': mean_recall, 'std': std_recall}

    print(f'{name}:')
    print(f'  Recall promedio: {mean_recall:.4f}')
    print(f'  Desviación estándar: {std_recall:.4f}\n')

print('Comparación técnica completada.')
# Out:
# Iniciando validación cruzada con SMOTE (Métrica: Recall)...
#
# Decision Tree:
#   Recall promedio: 0.4992
#   Desviación estándar: 0.0402
#
# Random Forest:
#   Recall promedio: 0.5160
#   Desviación estándar: 0.0474
#
# KNN:
#   Recall promedio: 0.6544
#   Desviación estándar: 0.0244
#
# Comparación técnica completada.

# %% [markdown]
# ## Optimización y Feature Importance
#
# ### Subtask:
# Realizar un ajuste de hiperparámetros (GridSearchCV) para el modelo RandomForest y extraer la importancia de las variables para identificar los drivers reales de cancelación.

# %% [markdown]
# **Reasoning**:
# I will perform a grid search to optimize the Random Forest model's hyperparameters and then extract the feature importances to identify the key factors driving customer churn.

# %%
from sklearn.model_selection import GridSearchCV
import pandas as pd

# 1. Definir el diccionario de parámetros (param_grid)
# Nota: Como usamos un pipeline, los prefijos deben coincidir con el nombre dado al clasificador
param_grid = {
    'classifier__n_estimators': [100, 200],
    'classifier__max_depth': [5, 10, None],
    'classifier__min_samples_split': [2, 5]
}

# 2. Crear el pipeline con SMOTE y RandomForest
pipeline_rf = imbpipeline(steps=[
    ('oversample', SMOTE(random_state=5)),
    ('classifier', RandomForestClassifier(random_state=5, n_jobs=-1))
])

# 3. Configurar GridSearchCV
# Usamos recall como métrica objetivo y validación cruzada estratificada de 5 pliegues
# skf ya fue definido previamente en el kernel como StratifiedKFold(n_splits=5, ...)
grid_search = GridSearchCV(
    estimator=pipeline_rf,
    param_grid=param_grid,
    cv=skf,
    scoring='recall',
    n_jobs=-1
)

# 4. Entrenar con los datos de entrenamiento
print('Iniciando búsqueda de hiperparámetros...')
grid_search.fit(X_train, y_train)

# 5. Mostrar mejores parámetros y puntaje
print(f'Mejores parámetros: {grid_search.best_params_}')
print(f'Mejor Recall obtenido en CV: {grid_search.best_score_:.4f}')

# 6. Extraer importancia de las variables del mejor estimador
# Accedemos al paso 'classifier' del mejor pipeline encontrado
mejor_rf = grid_search.best_estimator_.named_steps['classifier']
importancias = mejor_rf.feature_importances_

# 7. Crear DataFrame de importancia de variables
df_importancia = pd.DataFrame({
    'Característica': X_train.columns,
    'Importancia': importancias
}).sort_values(by='Importancia', ascending=False)

print('\nTop 10 Drivers de Cancelación:')
display(df_importancia.head(10))
# Out:
# Iniciando búsqueda de hiperparámetros...
# Mejores parámetros: {'classifier__max_depth': 5, 'classifier__min_samples_split': 5, 'classifier__n_estimators': 100}
# Mejor Recall obtenido en CV: 0.7424
#
# Top 10 Drivers de Cancelación:
#                              Característica  Importancia
# 9                   Contract_Month-to-month     0.260440
# 14           PaymentMethod_Electronic check     0.188757
# 11                        Contract_Two year     0.128982
# 18                                   tenure     0.101726
# 10                        Contract_One year     0.076880
# 19                           ChargesMonthly     0.057982
# 20                             ChargesTotal     0.045986
# 2                         SeniorCitizen_Yes     0.044903
# 13    PaymentMethod_Credit card (automatic)     0.043156
# 12  PaymentMethod_Bank transfer (automatic)     0.031667

# %% [markdown]
# ## Conclusiones Ejecutivas y Serialización
#
# ### Subtask:
# Redactar una conclusión técnica simplificada, enfocarla en hallazgos accionables y métricas finales, y exportar los modelos entrenados utilizando joblib.

# %% [markdown]
# **Reasoning**:
# I will calculate the final evaluation metrics (Recall and AUC) on the test set for the optimized Random Forest model, print the executive summary of findings, and export the model to a .pkl file using joblib.

# %%
import joblib
from sklearn.metrics import recall_score, roc_auc_score

# 1. Evaluar el mejor modelo del paso anterior en el conjunto de prueba
mejor_modelo = grid_search.best_estimator_
y_pred_test = mejor_modelo.predict(X_test)
y_proba_test = mejor_modelo.predict_proba(X_test)[:, 1]

recall_final = recall_score(y_test, y_pred_test)
auc_final = roc_auc_score(y_test, y_proba_test)

# 2. Resumen ejecutivo de hallazgos
print('=== CONCLUSIONES EJECUTIVAS ===')
print(f'El modelo Random Forest optimizado alcanzó un Recall de {recall_final:.2%} y un AUC de {auc_final:.2%} en el conjunto de prueba.')
print('\nHallazgos accionables:')
print('- Los principales factores de riesgo identificados son los Contratos Mensuales y el uso de Cheque Electrónico como método de pago.')
print('- Se recomienda incentivar la migración a contratos anuales y métodos de pago automáticos para reducir la tasa de abandono.')

# 3. Serializar y guardar el modelo final
joblib.dump(mejor_modelo, 'modelo_churn_final.pkl')

# Opcionalmente, guardar otros modelos base (usando los nombres definidos en la validación cruzada anterior)
# Nota: En este flujo, guardaremos el clasificador final entrenado en el pipeline
print('\nModelo guardado exitosamente como: modelo_churn_final.pkl')
# Out:
# === CONCLUSIONES EJECUTIVAS ===
# El modelo Random Forest optimizado alcanzó un Recall de 73.40% y un AUC de 82.75% en el conjunto de prueba.
#
# Hallazgos accionables:
# - Los principales factores de riesgo identificados son los Contratos Mensuales y el uso de Cheque Electrónico como método de pago.
# - Se recomienda incentivar la migración a contratos anuales y métodos de pago automáticos para reducir la tasa de abandono.
#
# Modelo guardado exitosamente como: modelo_churn_final.pkl

# %% [markdown]
# ## CONCLUSIONES EJECUTIVAS
# El modelo Random Forest optimizado alcanzó un Recall de 73.40% y un AUC de 82.75% en el conjunto de prueba.
#
# Hallazgos accionables:
# - Los principales factores de riesgo identificados son los Contratos Mensuales y el uso de Cheque Electrónico como método de pago.
# - Se recomienda incentivar la migración a contratos anuales y métodos de pago automáticos para reducir la tasa de abandono.
